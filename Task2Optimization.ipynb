# %% [markdown]
# ## Homework 2.2
# ### Optimization, variant 3
# #### Sofiia Petryshyn, APPS UCU

# %% [markdown]
# ## Gross profit maximisation

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit, minimize
from scipy.optimize import rosen_der

np.random.seed(1729)
plt.rcParams['figure.figsize'] = 15, 8

# %%
# Production
goal = np.array([216.18616928, 195.718539, 176.8435644, 156.06823893, 161.2252143,\
 174.82359282, 183.53185311, 189.58580472, 203.11211409, 207.56262067,
 211.95970354, 213.57970776])
plt.plot(goal, label='goal')
plt.xlabel('Months')
plt.ylabel('Number of tonnes')
plt.title('Goal to sell the amount of tonnes during the year')
# Out:
# Text(0.5, 1.0, 'Goal to sell the amount of tonnes during the year')

# %%
# Prices limits
b = (85.0,135.)
bnds = [b for _ in range(w)]
bnds
# Out:
# [(85.0, 135.0),
#  (85.0, 135.0),
#  (85.0, 135.0),
#  (85.0, 135.0),
#  (85.0, 135.0),
#  (85.0, 135.0),
#  (85.0, 135.0),
#  (85.0, 135.0),
#  (85.0, 135.0),
#  (85.0, 135.0),
#  (85.0, 135.0),
#  (85.0, 135.0)]

# %% [markdown]
# ### Our demand

# %%
a = min(goal) #min forecast
b = max(goal) #max forecast

def elasticity_func(x):
    # return demand
    return b * np.exp(-0.26 * x) * 1e11 + a

pricing_level = np.linspace(70, 110, 100)
plt.plot(pricing_level, elasticity_func(pricing_level))
plt.xlabel('Price')
plt.ylabel('Demand')
plt.title('Elasticity Function over Demand and Price of the product');

# %% [markdown]
# ### Our price per saving

# %%
def inventory(x):
    a = 0.2
    return 250 * np.log(x + 5)

inv_level = np.linspace(0, 100, 100)
plt.plot(inv_level, inventory(inv_level))
plt.title('Costs for the inventory')
plt.xlabel('Number of items')
plt.ylabel('Price we pay');

# %%
# Inventory (how many items we can store) limit 1800 items
# x = price
def constraint(x):
    total_items = 1800.
    return total_items - sum([elasticity_func(i) for i in x])

con = {'type': 'ineq', 'fun': constraint}

# %%
from scipy.optimize import BFGS
from scipy.optimize import NonlinearConstraint

def cons_f(x):
    return [elasticity_func(xx) - goal[i] + margin for i, xx in enumerate(x)]


nonlinear_constraint = NonlinearConstraint(cons_f, -np.inf, 1, jac='cs', hess=BFGS())

# %%
def costs(i, price):
    demand = elasticity_func(np.array(price)) # demand on price = price
    num_of_items_in_inventory = goal[i] - demand
    if num_of_items_in_inventory < 0:
        num_of_items_in_inventory = 0
    inv_costs = inventory(num_of_items_in_inventory)
    return inv_costs

# %%
# Optimization problem 
# Revenue = sum(Price * Sales)

# Let's take 12 months 
w = 12

# Optimization function is:
def revenue(ind, p):
    a = p*elasticity_func(p) - costs(ind, p)
    return a

def obj(x):
    return -sum([revenue(ind, xx) for ind, xx in enumerate(x)])

# Sales function
def sales_function(x):
    return sum([elasticity_func(i) for i in x])

# %%
from scipy.optimize import rosen, rosen_der, rosen_hess, rosen_hess_prod
# initial approximation
x0 = 111. * np.ones(w)

# %% [markdown]
# ### SLSQP with Jacobian of Rosen Der & Linear and Non-linear constraint

# %%
cons = ([con, nonlinear_constraint])
# Find solution
solution = minimize(obj, x0, method='SLSQP',\
                    jac=rosen_der,
                    bounds=bnds, constraints=cons,\
                    options={'maxiter': 1000, 'ftol': 1e-06, 'iprint': 1,\
                            'disp': True, 'eps': 1.4901161193847656e-08})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-a3fcb82c8823> in <module>
#       5                     bounds=bnds, constraints=cons,\
#       6                     options={'maxiter': 1000, 'ftol': 1e-06, 'iprint': 1,\
# ----> 7                             'disp': True, 'eps': 1.4901161193847656e-08})
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     579
#     580     if constraints is not None:
# --> 581         constraints = standardize_constraints(constraints, x0, meth)
#     582
#     583     if meth == '_custom':
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/optimize/_minimize.py in standardize_constraints(constraints, x0, meth)
#     813         for i, con in enumerate(list(constraints)):
#     814             if isinstance(con, new_constraint_types):
# --> 815                 old_constraints = new_constraint_to_old(con, x0)
#     816                 constraints[i] = old_constraints[0]
#     817                 constraints.extend(old_constraints[1:])  # appends 1 if present
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/optimize/_constraints.py in new_constraint_to_old(con, x0)
#     350     # FIXME: when bugs in VectorFunction/LinearVectorFunction are worked out,
#     351     # use pcon.fun.fun and pcon.fun.jac. Until then, get fun/jac above.
# --> 352     pcon = PreparedConstraint(con, x0)
#     353     lb, ub = pcon.bounds
#     354
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/optimize/_constraints.py in __init__(self, constraint, x0, sparse_jacobian, finite_diff_bounds)
#     218                                  constraint.finite_diff_rel_step,
#     219                                  constraint.finite_diff_jac_sparsity,
# --> 220                                  finite_diff_bounds, sparse_jacobian)
#     221         elif isinstance(constraint, LinearConstraint):
#     222             fun = LinearVectorFunction(constraint.A, x0, sparse_jacobian)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/optimize/_differentiable_functions.py in __init__(self, fun, x0, jac, hess, finite_diff_rel_step, finite_diff_jac_sparsity, finite_diff_bounds, sparse_jacobian)
#     269
#     270         self._update_fun_impl = update_fun
# --> 271         update_fun()
#     272
#     273         self.v = np.zeros_like(self.f)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/optimize/_differentiable_functions.py in update_fun()
#     266
#     267         def update_fun():
# --> 268             self.f = fun_wrapped(self.x)
#     269
#     270         self._update_fun_impl = update_fun
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     263         def fun_wrapped(x):
#     264             self.nfev += 1
# --> 265             return np.atleast_1d(fun(x))
#     266
#     267         def update_fun():
#
# <ipython-input-47-c6dff9cd8e8f> in cons_f(x)
#       3
#       4 def cons_f(x):
# ----> 5     return [elasticity_func(xx) - goal[i] + margin for i, xx in enumerate(x)]
#       6
#       7
#
# <ipython-input-47-c6dff9cd8e8f> in <listcomp>(.0)
#       3
#       4 def cons_f(x):
# ----> 5     return [elasticity_func(xx) - goal[i] + margin for i, xx in enumerate(x)]
#       6
#       7
#
# NameError: name 'margin' is not defined

# %%
x = solution.x

# show final objective
print('Final Objective (Revenue): ' + str(-obj(x)))

# show initial sales
print('Final Sales: ' + str(sales_function(x)))
# Out:
# Final Objective (Revenue): 206491.81944440305
# Final Sales: 1948.7238706226915

# %%
x
# Out:
# array([111., 111., 111., 111., 111., 111., 111., 111., 111., 111., 111.,
#        111.])

# %% [markdown]
# ### SLSQP without Jacobian

# %%
cons = ([con, nonlinear_constraint])
# Find solution
solution = minimize(obj, x0, method='SLSQP',\
                    bounds=bnds, constraints=cons,\
                    options={'maxiter': 1000, 'ftol': 1e-06, 'iprint': 1,\
                            'disp': True, 'eps': 1.4901161193847656e-08})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-77ccaac1f55b> in <module>
#       4                     bounds=bnds, constraints=cons,\
#       5                     options={'maxiter': 1000, 'ftol': 1e-06, 'iprint': 1,\
# ----> 6                             'disp': True, 'eps': 1.4901161193847656e-08})
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     579
#     580     if constraints is not None:
# --> 581         constraints = standardize_constraints(constraints, x0, meth)
#     582
#     583     if meth == '_custom':
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/optimize/_minimize.py in standardize_constraints(constraints, x0, meth)
#     813         for i, con in enumerate(list(constraints)):
#     814             if isinstance(con, new_constraint_types):
# --> 815                 old_constraints = new_constraint_to_old(con, x0)
#     816                 constraints[i] = old_constraints[0]
#     817                 constraints.extend(old_constraints[1:])  # appends 1 if present
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/optimize/_constraints.py in new_constraint_to_old(con, x0)
#     350     # FIXME: when bugs in VectorFunction/LinearVectorFunction are worked out,
#     351     # use pcon.fun.fun and pcon.fun.jac. Until then, get fun/jac above.
# --> 352     pcon = PreparedConstraint(con, x0)
#     353     lb, ub = pcon.bounds
#     354
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/optimize/_constraints.py in __init__(self, constraint, x0, sparse_jacobian, finite_diff_bounds)
#     218                                  constraint.finite_diff_rel_step,
#     219                                  constraint.finite_diff_jac_sparsity,
# --> 220                                  finite_diff_bounds, sparse_jacobian)
#     221         elif isinstance(constraint, LinearConstraint):
#     222             fun = LinearVectorFunction(constraint.A, x0, sparse_jacobian)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/optimize/_differentiable_functions.py in __init__(self, fun, x0, jac, hess, finite_diff_rel_step, finite_diff_jac_sparsity, finite_diff_bounds, sparse_jacobian)
#     269
#     270         self._update_fun_impl = update_fun
# --> 271         update_fun()
#     272
#     273         self.v = np.zeros_like(self.f)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/optimize/_differentiable_functions.py in update_fun()
#     266
#     267         def update_fun():
# --> 268             self.f = fun_wrapped(self.x)
#     269
#     270         self._update_fun_impl = update_fun
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     263         def fun_wrapped(x):
#     264             self.nfev += 1
# --> 265             return np.atleast_1d(fun(x))
#     266
#     267         def update_fun():
#
# <ipython-input-47-c6dff9cd8e8f> in cons_f(x)
#       3
#       4 def cons_f(x):
# ----> 5     return [elasticity_func(xx) - goal[i] + margin for i, xx in enumerate(x)]
#       6
#       7
#
# <ipython-input-47-c6dff9cd8e8f> in <listcomp>(.0)
#       3
#       4 def cons_f(x):
# ----> 5     return [elasticity_func(xx) - goal[i] + margin for i, xx in enumerate(x)]
#       6
#       7
#
# NameError: name 'margin' is not defined

# %%
x = solution.x

# show final objective
print('Final Objective (Revenue): ' + str(-obj(x)))

# show initial sales
print('Final Sales: ' + str(sales_function(x)))
# Out:
# Final Objective (Revenue): 239112.8402821657
# Final Sales: 1920.2214501708102

# %%
x
# Out:
# array([135.        , 135.        , 106.71901577, 135.        ,
#        135.        , 105.27465553, 135.        , 135.        ,
#        135.        , 135.        , 135.        , 135.        ])

# %% [markdown]
# ### SLSQP with Three Linear Constrains

# %%
margin = 3.

def constraint2(x):
    return sum(np.ceil([elasticity_func(xx) - goal[i] + margin for i, xx in enumerate(x)]))
               
con2 = {'type': 'ineq', 'fun': constraint2}

def constraint3(x):
    return sum(np.ceil([-elasticity_func(xx) + (goal[i] + margin) for i, xx in enumerate(x)]))

con3 = {'type': 'ineq', 'fun': constraint3}

# %%
cons = ([con, con2, con3])
# Find solution
solution = minimize(obj, x0, method='SLSQP',\
                    bounds=bnds, constraints=cons,\
                    options={'maxiter': 1000, 'ftol': 1e-06, 'iprint': 1,\
                            'disp': True, 'eps': 1.4901161193847656e-08})
# Out:
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -309908.7542981285
#             Iterations: 12
#             Function evaluations: 117
#             Gradient evaluations: 8

# %%
x = solution.x

# show final objective
print('Final Objective (Revenue): ' + str(-obj(x)))

# show initial sales
print('Final Sales: ' + str(sales_function(x)))
# Out:
# Final Objective (Revenue): 309908.7542981285
# Final Sales: 2706.9985969552736

# %%
x
# Out:
# array([134.99999578, 134.99999577, 134.99999573, 134.99999578,
#        134.99999579,  94.8886356 ,  94.89153508, 134.99999577,
#        134.99999578, 134.99999577, 134.99999577, 134.99999577])

# %% [markdown]
# #### Conclusions:
# We did three different ways to construct the prediction of the most optimal prices.\
# ##### Constrains:
# 1. On the inventory that we can store
# 2. On the demand that we want to be the one that follows the forecast
# It turned out that the best `Revenue = 309908.7542981285` and the most items are sold we get from method of minimisation `SLSQR`, where we set 3 linear constrains with a particular margin for two of them that works for demand.\
# In this case we just set the maximum prices everywhere, just not in the cases of the lowest demand during the year.\
#
# Other thechnic is `SLSQR`, `Revenue = 239112.8402821657`, sales are lower. Here we use Non-linear constrain for the demand and we can observe two months to be about of the average.\
#
# Next technic is to use `SLSQR` with the Jacobian being calculated by `Rosen Derivative`. This method always gives as an average, so we have the lowest Revenue and Sales.
